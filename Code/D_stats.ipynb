# %%
from pathlib import Path
import os.path
import os
import numpy as np
import re
import pandas as pd
import shutil 
import networkx as nx
import dynetx as dn
import powerlaw
#from networkx.algorithms import community
import networkx.algorithms.community as nxcom
import community as community_louvain
import matplotlib.pyplot as plt
import time
import collections

# %%
soft_path = 'D:/mm_thesis/Software_graphs/D_graph/'

softwareList = os.listdir(soft_path)
soft_files = [(os.path.join(soft_path,infile)+"/") for infile in softwareList]
#csv_path = ("D:/mm_thesis/SIG_csv/")
csv_path = 'D:/mm_thesis/Software_graphs/D_graph/D_sys/'
csv_path_l = os.listdir(csv_path)
csv_files1 = [(os.path.join(csv_path,infile)+"/") for infile in csv_path_l if os.path.isdir(os.path.join(csv_path,infile))]

csv_files = [i for i in csv_files1 if i.find("Time") == -1]

# %%
for soft in csv_files:
    print('soft', soft)
    soft_all = soft[:-1]
    soft_st = soft_all.rfind('/')
    soft_name = soft_all[soft_st+1 :]
    name_save = soft_name +'_Inh_m.csv'
    c_path = os.path.join(soft,name_save)
    print(c_path)
    soft_list = os.listdir(soft)
    
    
    soft_files = [(os.path.join(soft,infile )+"/")for infile in soft_list if os.path.isdir(os.path.join(soft,infile))]
# Out:
# soft D:/mm_thesis/D_graph/D_sys/Cassandra/
# D:/mm_thesis/D_graph/D_sys/Cassandra/Cassandra_Inh_m.csv
# soft D:/mm_thesis/D_graph/D_sys/Chukwa/
# D:/mm_thesis/D_graph/D_sys/Chukwa/Chukwa_Inh_m.csv
# soft D:/mm_thesis/D_graph/D_sys/httpClient/
# D:/mm_thesis/D_graph/D_sys/httpClient/httpClient_Inh_m.csv
# soft D:/mm_thesis/D_graph/D_sys/Ivy/
# D:/mm_thesis/D_graph/D_sys/Ivy/Ivy_Inh_m.csv
# soft D:/mm_thesis/D_graph/D_sys/Jena/
# D:/mm_thesis/D_graph/D_sys/Jena/Jena_Inh_m.csv

# %%
column_names = ['Version','t_stmp','no_nodes', 'no_edges','avg_degree',
                'no_comm','avg_shortest_path','sub_density',
                'avg_clust','SCC','WCC', 'LWC_nodes','LWC_edgeds','inCount','outCount' ]

for soft in csv_files:
    print('soft', soft)
    soft_all = soft[:-1]
    soft_st = soft_all.rfind('/')
    soft_name = soft_all[soft_st+1 :]
    soft_list = os.listdir(soft)
    
    soft_files = [(os.path.join(soft,infile )+"/")for infile in soft_list if os.path.isdir(os.path.join(soft,infile))]
#     soft_dir = [(os.path.join(soft,infile )+"/")for infile in soft_list if os.path.isdir(os.path.join(soft,infile))]
#     print(soft_files)
    net_list = []
    for ver in soft_files:
#         print(f_d)
#         print('ver', ver)
        f1 = os.listdir(ver)
#         f2 = [ os.path.join(ver,l) for l in f1 if (os.path.isdir(os.path.join(ver,l)) and l.find("CDot_csv")!= -1)  ]
#         f2 = [ os.path.join(ver,l) for l in f1 if (os.path.isdir(os.path.join(ver,l)) and l.find("CollDot_csv")!= -1)  ]
        f2 = [ os.path.join(ver,l) for l in f1 if (os.path.isdir(os.path.join(ver,l)) and l.find("InhDot_csv")!= -1)  ]
        
        
        for  f_d in f2:
#             print(f_d)
            net_dir = os.listdir(f_d)
    
            net_f = [d for d in net_dir if d.find('p_edges')!= -1]
#             print('net_f    ', net_f )
            net_path =  f_d+"/" +net_f[0] 
            net_files = net_path
#             print('net_path :' ,net_path)
            net_list.append(net_files)
    print('net_list', len(net_list))
#     for i in net_list:
#         print(i)
#     print('intialize info list for soft', soft)
    info_list = []
    x = 0
    
    for i in net_list:
#        
        e1 =  pd.read_csv(i)
        i_name   = e1["Version"].tolist()[0]
        print('i_name  ',i_name)
        ts = e1['t_stmp'].tolist()[0]
        #         print(ts)
#         x = i_name
        ts = e1.at[0,'t_stmp']
        print(ts)
        print('i   :',i)
#   
        sub = nx.from_pandas_edgelist(e1, source = 'source', target='target',edge_attr=True, create_using=nx.MultiDiGraph())
# #                                       nx.DiGraph())
        
       
        
        
        no_nodes, no_edges,avg_deg,no_comm, gc_avg_shortest_path,sub_density,avg_clust,SCC,WCC,LWC_nodes,LWC_edges,incount, outcount =get_info_path(sub)
         
        info_list.append([i_name,ts,no_nodes,no_edges, avg_deg,no_comm,
                          gc_avg_shortest_path,sub_density,avg_clust,SCC,WCC,LWC_nodes,LWC_edges,incount,outcount])
    
    print("putting info ", soft)
    
    
    nt_d = pd.DataFrame(info_list)
#     print(nt_d.head())
    nt_d.columns = column_names
    name_save = soft_name +'_cdot_m.csv'
    name_save = soft_name +'_coll_m.csv'
    name_save = soft_name +'_Inh_m.csv'
    c_path = os.path.join(soft,name_save)

    print(C_path)
    nt_d.to_csv(C_path, encoding='utf-8', index=False)
         
    
            


    #     C_path = soft+'info_cdot_m.csv'
#     C_path =soft +'info_colldot_m.csv'
#     C_path =soft +'info_Inhdot_m.csv'
# Out:
# soft D:/mm_thesis/D_graph/Cassandra/
# net_list 82
# i_name   cassandra-cassandra-0.3.0-final
# 1254866400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_030/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.4.0-final
# 1253224800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_040/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.4.1
# 1260399600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_041/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.4.2
# 1239400800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_042/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.5.0
# 1263769200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_050/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.5.1
# 1266879600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_051/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.0
# 1269730800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_060/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.1
# 1271282400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_061/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.10
# 1295391600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0610/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.11
# 1296082800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0611/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.12
# 1297897200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0612/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.13
# 1302645600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0613/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.2
# 1274652000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_062/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.3
# 1277503200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_063/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.4
# 1280181600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_064/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.5
# 1282514400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_065/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.6
# 1287093600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_066/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.7
# 1286748000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_067/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.8
# 1289602800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_068/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.6.9
# 1301608800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_069/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.0
# 1306879200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_070/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.1
# 1317506400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_071/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.10
# 1320015600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0710/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.2
# 1297724400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_072/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.3
# 1301781600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_073/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.4
# 1322866800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_074/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.5
# 1303423200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_075/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.6
# 1305237600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_076/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.6-2
# 1305842400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0762/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.7
# 1309989600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_077/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.8
# 1311199200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_078/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.7.9
# 1314741600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_079/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.0
# 1306706400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_080/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.1
# 1308866400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_081/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.10
# 1343858400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_0810/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.2
# 1311285600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_082/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.3
# 1302213600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_083/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.4
# 1318024800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_084/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.5
# 1304892000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_085/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.6
# 1316037600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_086/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.7
# 1304978400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_087/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.8
# 1297465200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_088/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-0.8.9
# 1321052400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_089/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.0
# 1320879600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_100/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.1
# 1319752800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_101/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.10
# 1333576800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1010/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.11
# 1343340000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1011/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.12
# 1348437600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1012/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.2
# 1302472800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_102/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.3
# 1321311600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_103/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.4
# 1322175600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_104/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.5
# 1322521200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_105/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.6
# 1323817200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_106/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.7
# 1326409200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_107/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.8
# 1329865200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_108/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.0.9
# 1330815600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_109/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.0
# 1334872800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_110/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.1
# 1325804400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_111/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.10
# 1385938800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1110/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.11
# 1366149600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1111/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.12
# 1369173600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1112/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.2
# 1340920800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_112/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.3
# 1325977200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_113/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.4
# 1344895200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_114/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.5
# 1341784800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_115/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.6
# 1355094000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_116/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.7
# 1353970800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_117/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.8
# 1355439600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_118/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.1.9
# 1358118000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_119/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.0
# 1356735600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_120/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.1
# 1359068400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_121/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.10
# 1379541600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_1210/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.2
# 1361314800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_122/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.3
# 1363215600
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_123/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.4
# 1375567200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_124/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.5
# 1368568800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_125/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.6
# 1372111200
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_126/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.7
# 1374616800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_127/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.8
# 1374962400
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_128/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-1.2.9
# 1377468000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_129/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-2.0.0
# 1377640800
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_200/InhDot_csv/Ver_stmp_edges.csv
# i_name   cassandra-cassandra-2.0.1
# 1379628000
# i   : D:/mm_thesis/D_graph/Cassandra/Cassandra_201/InhDot_csv/Ver_stmp_edges.csv
# putting info  D:/mm_thesis/D_graph/Cassandra/
# D:/mm_thesis/D_graph/Cassandra/info_Inhdot_m.csv
# soft D:/mm_thesis/D_graph/Chukwa/
# net_list 6
# i_name   chukwa-release-0.1.2
# 1243029600
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_012/InhDot_csv/Ver_stmp_edges.csv
# i_name   chukwa-chukwa-0.2.0
# 1246399200
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_020/InhDot_csv/Ver_stmp_edges.csv
# i_name   chukwa-chukwa-0.4.0
# 1271023200
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_040/InhDot_csv/Ver_stmp_edges.csv
# i_name   chukwa-chukwa-0.5.0
# 1326150000
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_050/InhDot_csv/Ver_stmp_edges.csv
# i_name   chukwa-chukwa-0.7.0
# 1450652400
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_070/InhDot_csv/Ver_stmp_edges.csv
# i_name   chukwa-chukwa-0.8.0
# 1466460000
# i   : D:/mm_thesis/D_graph/Chukwa/chukwa_080/InhDot_csv/Ver_stmp_edges.csv
# putting info  D:/mm_thesis/D_graph/Chukwa/
# D:/mm_thesis/D_graph/Chukwa/info_Inhdot_m.csv
# soft D:/mm_thesis/D_graph/httpClient/
# net_list 34
# i_name   httpcomponents-client-4_0_API_FREEZE
# 1216850400
# i   : D:/mm_thesis/D_graph/httpClient/HC_400.0/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.0.2-RC1
# 1283032800
# i   : D:/mm_thesis/D_graph/httpClient/HC_402.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.0.2-RC2
# 1283292000
# i   : D:/mm_thesis/D_graph/httpClient/HC_402.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.0.2-RC3
# 1283378400
# i   : D:/mm_thesis/D_graph/httpClient/HC_402.3/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.0.3-RC1
# 1284501600
# i   : D:/mm_thesis/D_graph/httpClient/HC_403.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.1-siteupdate
# 1297638000
# i   : D:/mm_thesis/D_graph/httpClient/HC_410.00/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.1-RC1
# 1294873200
# i   : D:/mm_thesis/D_graph/httpClient/HC_410.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.1-RC2
# 1294959600
# i   : D:/mm_thesis/D_graph/httpClient/HC_410.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.1-RC3
# 1295218800
# i   : D:/mm_thesis/D_graph/httpClient/HC_410.3/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2-RC1
# 1336860000
# i   : D:/mm_thesis/D_graph/httpClient/HC_420.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2-RC2
# 1337205600
# i   : D:/mm_thesis/D_graph/httpClient/HC_420.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.1-RC1
# 1340920800
# i   : D:/mm_thesis/D_graph/httpClient/HC_421.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.2-RC1
# 1350770400
# i   : D:/mm_thesis/D_graph/httpClient/HC_422.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.3-RC1
# 1357340400
# i   : D:/mm_thesis/D_graph/httpClient/HC_423.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.3-RC2
# 1357599600
# i   : D:/mm_thesis/D_graph/httpClient/HC_423.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.3-RC3
# 1357772400
# i   : D:/mm_thesis/D_graph/httpClient/HC_423.3/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.4-RC1
# 1365112800
# i   : D:/mm_thesis/D_graph/httpClient/HC_424.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.5-RC1
# 1366322400
# i   : D:/mm_thesis/D_graph/httpClient/HC_425.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.6-RC1
# 1377727200
# i   : D:/mm_thesis/D_graph/httpClient/HC_426.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.2.6-RC2
# 1378245600
# i   : D:/mm_thesis/D_graph/httpClient/HC_426.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3-RC1
# 1378677600
# i   : D:/mm_thesis/D_graph/httpClient/HC_430.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.1-RC1
# 1380800745
# i   : D:/mm_thesis/D_graph/httpClient/HC_431.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.1-RC2
# 1380820117
# i   : D:/mm_thesis/D_graph/httpClient/HC_431.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.2-RC1
# 1389740400
# i   : D:/mm_thesis/D_graph/httpClient/HC_432.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.3-RC1
# 1392937200
# i   : D:/mm_thesis/D_graph/httpClient/HC_433.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.4-RC1
# 1401487200
# i   : D:/mm_thesis/D_graph/httpClient/HC_434.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.5-RC1
# 1406671200
# i   : D:/mm_thesis/D_graph/httpClient/HC_435.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.3.6-RC1
# 1414882800
# i   : D:/mm_thesis/D_graph/httpClient/HC_436.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.4-RC1
# 1411336800
# i   : D:/mm_thesis/D_graph/httpClient/HC_440.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.4-RC2
# 1422313200
# i   : D:/mm_thesis/D_graph/httpClient/HC_440.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.4.1-RC1
# 1427151600
# i   : D:/mm_thesis/D_graph/httpClient/HC_441.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.5-RC1
# 1432332000
# i   : D:/mm_thesis/D_graph/httpClient/HC_450.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.5-RC2
# 1433023200
# i   : D:/mm_thesis/D_graph/httpClient/HC_450.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   httpcomponents-client-4.5.1-RC1
# 1441922400
# i   : D:/mm_thesis/D_graph/httpClient/HC_451.1/InhDot_csv/Ver_stmp_edges.csv
# putting info  D:/mm_thesis/D_graph/httpClient/
# D:/mm_thesis/D_graph/httpClient/info_Inhdot_m.csv
# soft D:/mm_thesis/D_graph/Ivy/
# net_list 18
# i_name   ant-ivy-1.4.1
# 1165705200
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_141/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0
# 1232233200
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0-rc1
# 1238450400
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0-alpha2
# 1184191200
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200.12/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0-rc2
# 1225753200
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0-beta1
# 1196895600
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200.21/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.0.0-beta2
# 1203894000
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_200.22/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.1.0
# 1253916000
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_210/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.1.0-rc1
# 1238450400
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_210.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.1.0-rc2
# 1246658400
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_210.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.2.0
# 1285192800
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_220/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.2.0-rc1
# 1277848800
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_220.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.3.0
# 1357772400
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_230/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.3.0-rc1
# 1334440800
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_230.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.3.0-rc2
# 1352070000
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_230.2/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.4.0
# 1418425200
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_240/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.4.0-rc1_OLD
# 1390172400
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_240.01/InhDot_csv/Ver_stmp_edges.csv
# i_name   ant-ivy-2.4.0-rc1
# 1394838000
# i   : D:/mm_thesis/D_graph/Ivy/ant_ivy_240.1/InhDot_csv/Ver_stmp_edges.csv
# putting info  D:/mm_thesis/D_graph/Ivy/
# D:/mm_thesis/D_graph/Ivy/info_Inhdot_m.csv
# soft D:/mm_thesis/D_graph/Jena/
# net_list 7
# i_name   jena-jena-2.10.0
# 1361314800
# i   : D:/mm_thesis/D_graph/Jena/jena_210/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.10.1
# 1368223200
# i   : D:/mm_thesis/D_graph/Jena/jena_210.1/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.11.0
# 1378936800
# i   : D:/mm_thesis/D_graph/Jena/jena_211/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.7.1
# 1339538400
# i   : D:/mm_thesis/D_graph/Jena/jena_271/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.7.2
# 1340834400
# i   : D:/mm_thesis/D_graph/Jena/jena_272/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.7.3
# 1344376800
# i   : D:/mm_thesis/D_graph/Jena/jena_273/InhDot_csv/Ver_stmp_edges.csv
# i_name   jena-jena-2.7.4
# 1350684000
# i   : D:/mm_thesis/D_graph/Jena/jena_274/InhDot_csv/Ver_stmp_edges.csv
# putting info  D:/mm_thesis/D_graph/Jena/
# D:/mm_thesis/D_graph/Jena/info_Inhdot_m.csv

# %%
def get_info_path (sub):
    
#      S I Z E   I N F O 
    no_edges = sub.number_of_edges()
    no_nodes = sub.number_of_nodes()
    #nnodes = sub.number_of_nodes()
#     sub_in = sub.in_degree()
#     sub_out = sub.out_degree()
#     avg_deg_in = sum(d for n, d in sub.in_degree()) / float(no_nodes)

#     avg_deg_out = sum(d for n, d in sub.out_degree()) / float(no_nodes)
    nodes_sub = [n for n in sub]
    avg_deg_in = 0
    avg_deg_out = 0
    for i in nodes_sub: 
        avg_deg_in =  avg_deg_in +  sub.in_degree(i)
        avg_deg_out =  avg_deg_out +  sub.out_degree(i)
        
    avg_deg = avg_deg_in / float(no_nodes) 
#     avg_deg_out = avg_deg_out / float(no_nodes)

####  D E G R E E   D I S T R I B U T I O N 

    in_degrees = sub.in_degree() # dictionary node:degree
    in_values = [val for (node, val) in sorted(in_degrees(), key=lambda pair: pair[0], reverse = True)]
    inCount = collections.Counter(in_values)
    out_degrees = sub.out_degree()
    out_values = [val for (node, val) in sorted(out_degrees(), key=lambda pair: pair[0],reverse= True)]
    outCount = collections.Counter(out_values)
    
#  G E T   T H E  C O N N E C T E D  C O M P O N E N T S     
    
    SCC = nx.number_strongly_connected_components(sub)
    WCC = nx.number_weakly_connected_components(sub)     # To get the shortest patg 

    largest_cc = max(nx.weakly_connected_components(sub), key=len)
    s = sub.subgraph(largest_cc)
    
    LWC_edges = s.number_of_edges()
    LWC_nodes = s.number_of_nodes()
        
    
    
    sub_density = nx.density(sub)
#     print("DENSITY :", sub_density)
    sub_un = sub.to_undirected()
    
#     part = community_louvain.best_partition(sub_un)
#     print( max(part.values())
    
#     reslt = nxcom.girvan_newman(sub_un)
#     print(type(reslt))
#     print(reslt)
#     comm = next(reslt)
#     print(comm)
#     try:
        
# #         comm = next(reslt)
#         no_comm = len(comm)
#         print(no_comm)
#     except Exception as e:
#         print(e)
#         avg_clust = 0
    communities = sorted(nxcom.greedy_modularity_communities(sub_un), key=len, reverse=True)
    no_comm = len(communities)
#     print("comm", no_comm)
#     print(communities[0])
    
    di_sub = nx.DiGraph(sub)
    try:
        avg_clust = nx.average_clustering (di_sub)
#         print('cluster' , avg_clust)
#     except Exception as e:
#         print(e)
    except Exception:
        avg_clust = 0
        print('err clust')
        pass 
    
#     fit = powerlaw.Fit(s.nodes)
#     p_law = fit.power_law.alpha
#     print("power_law", p_law)
    gc_avg_shortest_path = 0
    
    try:
#         st1 = time.time()
        gc_avg_shortest_path = nx.average_shortest_path_length(s)
#         end1 = time.time()
#         print('time for path', end1- st1)
        
    except Exception as e:
        print(e)
        
    except Exception:
        print("no wCC")
        gc_avg_shortest_path = 0
        
        pass
        
   
    return (no_nodes,no_edges,avg_deg, no_comm, gc_avg_shortest_path,sub_density,avg_clust,SCC,WCC,
            LWC_nodes,LWC_edges,in_values,out_values)
